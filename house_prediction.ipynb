# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
boston=pd.read_csv('data/BostonHousing.csv')

# %% [markdown]
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.

# %%
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='str')

# %%
type(boston)
# Out:
# pandas.DataFrame

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston.rename(columns={'medv':'price'},inplace=True)

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
###summarizing the stats of the dataset

boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
###checking the missing values


boston.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# price      0
# dtype: int64

# %%
boston.dropna(inplace=True)

# %%
boston.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# price      0
# dtype: int64

# %%
###exploratory data analysis(EDA)
##01.correlation:says both strongly the independent and dependent features are realted to eachother
boston.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.201470  0.407544 -0.057032  0.420611 -0.219433  0.354739
# zn      -0.201470  1.000000 -0.536624 -0.043209 -0.518108  0.311173 -0.569695
# indus    0.407544 -0.536624  1.000000  0.062351  0.762937 -0.394193  0.646157
# chas    -0.057032 -0.043209  0.062351  1.000000  0.090371  0.091468  0.087384
# nox      0.420611 -0.518108  0.762937  0.090371  1.000000 -0.302751  0.732899
# rm      -0.219433  0.311173 -0.394193  0.091468 -0.302751  1.000000 -0.240286
# age      0.354739 -0.569695  0.646157  0.087384  0.732899 -0.240286  1.000000
# dis     -0.380572  0.665634 -0.709741 -0.098696 -0.771108  0.203507 -0.751500
# rad      0.624932 -0.314530  0.597721 -0.008872  0.611942 -0.210718  0.460090
# tax      0.582243 -0.315991  0.720800 -0.037146  0.666959 -0.292794  0.508338
# ptratio  0.291731 -0.392956  0.382633 -0.121830  0.188830 -0.357612  0.264496
# ...

# %%
import seaborn as sns
sns.pairplot(boston)

# %%
plt.scatter(boston['crim'],boston['price'])
plt.xlabel('crime_rate')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
sns.regplot(x='rm',y='price',data=boston)
##from this plot we can say that using fitline that rm and price both are positively related
# Out:
# <Axes: xlabel='rm', ylabel='price'>

# %%
###preparing datset for model training
##01.separating dependent and independent features
X=boston.iloc[:,:-1]#considering all rows and columns excluding last columnn(independent features)
y=boston.iloc[:,-1]#considering all rows and only last column(dependent features)

# %%
X
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: price, Length: 501, dtype: float64

# %%
###train test split
from sklearn.model_selection import train_test_split

#x_train and y_train is used to train the model
#X_test and y_test is used to test the model for prediction
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42)

# %%
X_train
# Out:
#          crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 120   0.06899   0.0  25.65     0  0.581  5.870  69.7   2.2577    2  188
# 47    0.22927   0.0   6.91     0  0.448  6.030  85.5   5.6894    3  233
# 17    0.78420   0.0   8.14     0  0.538  5.990  81.7   4.2579    4  307
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0   2.9084   24  666
# 362   3.67822   0.0  18.10     0  0.770  5.362  96.2   2.1036   24  666
# ..        ...   ...    ...   ...    ...    ...   ...      ...  ...  ...
# 110   0.10793   0.0   8.56     0  0.520  6.195  54.4   2.7778    5  384
# 275   0.09604  40.0   6.41     0  0.447  6.854  42.8   4.2673    4  254
# 353   0.01709  90.0   2.02     0  0.410  6.728  36.1  12.1265    5  187
# 440  22.05110   0.0  18.10     0  0.740  5.818  92.4   1.8662   24  666
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9   2.2110    5  384
#
#      ptratio       b  lstat
# 120     19.1  389.15  14.37
# 47      17.9  392.74  18.80
# ...

# %%
y_train
# Out:
# 120    22.0
# 47     16.6
# 17     17.5
# 468    19.1
# 362    20.8
#        ...
# 110    21.7
# 275    32.0
# 353    30.1
# 440    10.5
# 106    19.5
# Name: price, Length: 350, dtype: float64

# %%
###standardscaling the datset

from  sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
with open('scaling.pkl','wb') as file:
          pickle.dump(scaler ,file)

# %%
###training the model

from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
###print the coefficients and intercepts
regression.coef_
# Out:
# array([-0.81333048,  1.25793481,  0.55901585,  0.62921378, -1.90632294,
#         2.57817719,  0.56191215, -2.87590127,  2.74653476, -2.09048251,
#        -2.03201533,  1.20544035, -4.54581734])

# %%
print(regression.intercept_)
# Out:
# 22.840285714285717

# %%
#on which parameters the modelhas been trained

regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
###prediction with test data
reg_pred=regression.predict(X_test)
reg_pred
# Out:
# array([11.18470187, 23.00563404, 15.50555989, 33.91377385, 22.85033375,
#        11.52120718, 12.87909485, 19.68559436, 21.04526151, 11.33123451,
#        18.86863905, 30.14960371, -1.11832542, 25.62332993,  2.86892345,
#         8.03143995, 23.74581797, 18.48006615, 25.08802436, -6.69909852,
#        13.05721404, 18.91286419, 27.07854376, 19.68268673, 22.34432239,
#        16.60552708, 28.66835041, 26.17851266, 18.28698048, 20.9648065 ,
#        20.99274995, 30.45869773, 17.88348023, 31.45467817, 31.04568544,
#        21.85781507,  7.19466076, 23.35955087,  7.67299185, 25.28772941,
#        13.06751099, 35.87850613, 14.55527766, 30.48366917, 12.54855213,
#        28.33694316, 30.32808565, 19.98874661, 18.58460772, 13.49196425,
#        23.92954047, 33.0591127 , 16.37371772, 11.0238909 , 34.65082608,
#        33.84119359, 17.64417679, 18.519131  , 16.23822474, 27.42388838,
#        20.31971468, 40.40623824, 20.22919151,  8.17914399, 25.84915232,
# ...

# %%
###lets plot some plots to know wether the obtained predictions are good or bad
##plot a scatter plot for the prediciton
plt.scatter(y_test,reg_pred)

#from thr plot we can say that we find a linear pattern..it mean the predicitons are  good it mean our model performed well

# %%
###prediciton with residuals
residuals=y_test-reg_pred
residuals
# Out:
# 367    11.915298
# 76     -3.005634
# 380    -5.105560
# 160    -6.913774
# 108    -3.050334
#          ...
# 24     -0.109736
# 227    -1.048031
# 266     0.148491
# 435     1.444595
# 5       3.139275
# Name: price, Length: 151, dtype: float64

# %%
#noe plottinf the residuals
sns.displot(residuals,kind='kde')

##from the plot we can say that he residuals are between -10 to +10

# %%
##scatter plot w.r.t prediction and residuals
plt.scatter(reg_pred,residuals)
###from the plot we found that both are uniformly distributed

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

mean_squared_error(y_test,reg_pred)
# Out:
# 18.380869507282043

# %%
mean_absolute_error(y_test,reg_pred)
# Out:
# 3.0541387622304703

# %%
RMSE=np.sqrt(mean_squared_error(y_test,reg_pred))
print(RMSE)
# Out:
# 4.287291628438873

# %%
## findinh r^2 and adjusted r^2 values to know how wel; the regression model is fitting the data
from sklearn.metrics import r2_score
score=r2_score(reg_pred,y_test)
score
# Out:
# 0.7507988784477893

# %%
#adjusted r^2 score
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.7271520566946598

# %%
##NEW DATA PREDICTION
#when ever we get the new data we need to standardize the data then we need to use it for prediciton
#transfromaiton of the newdata
scaler.transform(X_train[0].reshape(1,-1))
# Out:
# c:\Users\trive\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.50992318, -0.5289195 , -1.35162734, -1.33554648, -3.14649163,
#         -9.63902733, -2.50721174, -2.04352405, -1.22860561, -2.450388  ,
#         -8.28730029, -4.04929584, -1.74412148]])

# %%
regression.predict(X_train[0].reshape(1,-1))
# Out:
# array([22.46591956])

# %%
###PICKLING THE MODEL FILE FOR DEPLOYMENT

import pickle
with open('regressionmodel.pkl','wb') as file:
          pickle.dump(regression ,file)

# %%
with open('regressionmodel.pkl','rb') as file:
    pickled_model=pickle.load(file)

# %%
###prediction

pickled_model.predict(X_train[0].reshape(1,-1))
# Out:
# array([22.46591956])

# %%
print(X.shape)
print(X.columns)
# Out:
# (501, 13)
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat'],
#       dtype='str')
